# %% [markdown]
# # Full Name : HIND MOUTALATTIF
#
# #### Data Science and Business Analytics Intern at @The Sparks Foundation
# ## TSF GRIP TASK
# ### Task 4 : Eploratory Data Analysis-Terrorism
#
# As a security/defense analyst, try to find out the hot zone of terrorism
#
#
# ### Dataset: https://bit.ly/2TK5Xn5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("globalterrorismdb_0718dist.csv", encoding ='latin1')
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended', 'resolution', 'country', 'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr', 'alternative', 'alternative_txt', 'multiple', 'success', 'suicide', 'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2', 'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'cla
# ...

# %%
##where are the dangerous countries

# %%
df['country_txt'].value_counts().head(30)
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: country_txt, dtype: int64

# %%
df['country_txt'].value_counts()
plt.figure(figsize=(10,8))
sns.barplot(x=df['country_txt'].value_counts()[:20].index , y=df['country_txt'].value_counts()[:20].values)
plt.title('Hot Zones - Countries')
plt.xticks(rotation=90)
plt.xlabel('Countries')
plt.ylabel('no. of Attacks')
plt.show()

# %% [markdown]
# # Where are the safest zones -top 10 countries?

# %%
df['country_txt'].value_counts().tail(10)
# Out:
# Vatican City           1
# Falkland Islands       1
# St. Lucia              1
# North Korea            1
# New Hebrides           1
# International          1
# Wallis and Futuna      1
# South Vietnam          1
# Andorra                1
# Antigua and Barbuda    1
# Name: country_txt, dtype: int64

# %% [markdown]
# # where are the dangerous zones--- REGION

# %%
df['region_txt'].value_counts()
plt.figure(figsize=(10,8))
sns.countplot(x='region_txt' , data=df)

plt.xticks(rotation=90)
plt.show()

# %%
df['region_txt'].value_counts().idxmax()
# Out:
# 'Middle East & North Africa'

# %%
##the hot zone : Middle East & North Africa

# %% [markdown]
# # where are the safe zones - Region?

# %%
df['region_txt'].value_counts().idxmin()
# Out:
# 'Australasia & Oceania'

# %%
##the safe zone : Australasia & Oceania

# %% [markdown]
# # where are the dangerous zones - Cities?

# %%
df['city'].value_counts()
# Out:
# Unknown      9775
# Baghdad      7589
# Karachi      2652
# Lima         2359
# Mosul        2265
#              ...
# Hotwag          1
# Ostend          1
# Balughata       1
# Jikoyi          1
# Kubentog        1
# Name: city, Length: 36674, dtype: int64

# %%
df=df[df['city'] != 'Unknown']

# %%
df.shape
# Out:
# (171916, 133)

# %%
df['city'].value_counts()
plt.figure(figsize=(10,8))
sns.barplot(x=df['city'].value_counts()[:20].index , y=df['city'].value_counts()[:20].values)
plt.title('Hot Zones - City')
plt.xticks(rotation=90)
plt.xlabel('Cities')
plt.ylabel('no. of Attacks')
plt.show()

# %%
## the hotest city:

# %%
df['city'].value_counts().idxmax()
# Out:
# 'Baghdad'

# %%
##the safest city:

# %%
df['city'].value_counts().idxmin()
# Out:
# 'Dhaperhat'

# %%
df['motive'].isnull().sum()
# Out:
# 123269

# %% [markdown]
# # Terror Attacks 1970 -2017

# %%
plt.subplots(figsize=(14,10))
sns.countplot(x='iyear' , data=df , palette = 'tab10')
plt.xticks(rotation=90)
plt.title('Terror Attacks 1970 - 2017')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# # Number of Attacks vs.Attack Type

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=df['attacktype1_txt'], order=df['attacktype1_txt'].value_counts().index , palette='tab10')
plt.xticks(rotation = 90)
plt.xlabel('attacktype')
plt.ylabel('no. of attacks')
plt.show()
